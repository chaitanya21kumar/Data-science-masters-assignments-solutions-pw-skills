# %% [markdown]
# ## Question 1: Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot
# ---

# %% [markdown]
# Seaborn is a popular data visualization library in Python that is built on top of Matplotlib. It provides a high-level interface for creating informative and visually appealing statistical graphics. Here are five commonly used plots in Seaborn and their uses:
#
# Scatter Plot: A scatter plot displays the relationship between two numeric variables. It is useful for visualizing the correlation or patterns between two continuous variables. Seaborn provides additional functionality to enhance scatter plots, such as adding a regression line or color-coding the points based on a categorical variable.
#
# Line Plot: A line plot shows the relationship between two variables with continuous data points connected by straight lines. It is commonly used to visualize trends over time or to compare multiple lines representing different categories. Seaborn offers options to customize the appearance of lines and markers, and it can also handle time-series data.
#
# Bar Plot: A bar plot is used to compare categorical data by displaying rectangular bars with heights or lengths proportional to the values they represent. It is effective in showing the distribution or comparison of categorical variables. Seaborn allows customization of bar plots, such as adding error bars or grouping bars based on another categorical variable.
#
# Histogram: A histogram is a graphical representation that organizes numerical data into bins and displays the frequency or count of values falling into each bin. It provides an overview of the data's distribution, allowing you to identify patterns, skewness, or outliers. Seaborn enhances histograms by providing options for kernel density estimation (KDE) plots or applying multiple histograms for different subgroups.
#
# Heatmap: A heatmap represents data in a matrix format, where the values in the matrix are displayed using color variations. It is useful for visualizing the correlation or relationships between multiple variables simultaneously. Seaborn's heatmap offers customization options such as color palettes, annotations, and clustering, making it a powerful tool for exploring complex datasets.
#
# These are just a few examples of the plots available in Seaborn. The library also provides other plots like box plots, violin plots, count plots, and more, each with its specific use case for data analysis and visualization.

# %% [markdown]
# ## Question 2 : Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x = "timepoint" and y = "signal" for different events and regions.
# ### Note: timepoint, signal, event, and region are columns in the fmri dataset.
# ---

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
fmri_data=sns.load_dataset('fmri')
sns.lineplot(data=fmri_data , x='timepoint' , y='signal' , hue='event' , style='region')
plt.show()

# %% [markdown]
# ## Question 3: Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x ='pclass', y = 'age' and y = 'fare'.
# ### Note: pclass, age, and fare are columns in the titanic dataset.
# ---

# %%
titanic_data=sns.load_dataset('titanic')
plt.figure(figsize=(10,5))
plt.subplot(121)
sns.boxplot(data=titanic_data,x='pclass',y='age')
plt.title("box plot of age vs pclass")
plt.subplot(122)
sns.boxplot(data=titanic_data , x='pclass' , y='fare')
plt.title('box plot of fare vs pclass')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Question 4 : Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue parameter for the 'cut' column of the diamonds dataset
# ---

# %%
diamonds_data=sns.load_dataset('diamonds')
sns.histplot(data=diamonds_data,x='price',hue='cut',kde=True)
plt.title("histogram of diamond price by cut")
plt.xlabel("price")
plt.ylabel("frequency")
plt.show()

# %% [markdown]
# ## Question 5: Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column of the iris dataset
# ---

# %%
iris_data=sns.load_dataset('iris')
sns.pairplot(data=iris_data,hue='species')
plt.show()

# %% [markdown]
# ## Question 6 : Use the "flights" dataset from seaborn to plot a heatmap
# ---

# %%
flights_data=sns.load_dataset('flights')
flights_pivot=flights_data.pivot('month','year','passengers')
sns.heatmap(data=flights_pivot , annot=True , fmt='d',cmap='YlGnBu')
plt.title("passengers flights")
plt.xlabel("year")
plt.ylabel("month")
plt.show()
# Out:
# /tmp/ipykernel_95/182282487.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights_pivot=flights_data.pivot('month','year','passengers')
